# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the dataset 
data = pd.read_csv("Dataset .csv")
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# **DATA EXPLORATION**

# %%
#print the first 5 data 
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#print last five data
data.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %%
#Describing all numerical column with all statistical formulas
data.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
data.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %%
#checking the number of null values in all the coulumns
data.isnull().sum()         # here the cuisines have 9 null values
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#Drop all rows which have the null values
data = data.dropna() 
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# **TASK 1 (TOP CUISINES)**

# %% [markdown]
# **Determine the top 3 cusines**

# %%
#counting all the cuisines occurance in the dataset
grp = data["Cuisines"].value_counts()
print(grp)
# Out:
# Cuisines
# North Indian                       936
# North Indian, Chinese              511
# Chinese                            354
# Fast Food                          354
# North Indian, Mughlai              334
#                                   ...
# Kebab, Izgara                        1
# World Cuisine                        1
# World Cuisine, Mexican, Italian      1
# Kebab, Turkish Pizza, D�_ner         1
# Turkish Pizza                        1
# Name: count, Length: 1825, dtype: int64

# %%
#display the top 3 cuisines
print("The top 3 cuisines are :- ")
data1 = grp.head(3) 
print(data1)
# Out:
# The top 3 cuisines are :-
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %%
#bar graph gor displaying so
plt.title("Top 3 Cuisines", fontsize = 25)
sns.barplot(data = data1 ,color = "Hotpink", gap = 0.3)
# Out:
# <Axes: title={'center': 'Top 3 Cuisines'}, xlabel='Cuisines', ylabel='count'>

# %% [markdown]
# **% of restaurant that serve each of the top cuisines**

# %%
#finding the percentage of each tip cusines by the no. of restaurant
g= (grp/len(data))*100
print(g)
# Out:
# Cuisines
# North Indian                       9.809264
# North Indian, Chinese              5.355271
# Chinese                            3.709914
# Fast Food                          3.709914
# North Indian, Mughlai              3.500314
#                                      ...
# Kebab, Izgara                      0.010480
# World Cuisine                      0.010480
# World Cuisine, Mexican, Italian    0.010480
# Kebab, Turkish Pizza, D�_ner       0.010480
# Turkish Pizza                      0.010480
# Name: count, Length: 1825, dtype: float64

# %%
print("% of restaurant which serve each top cuisines")
#displaying top 3 from them
data1 = g.head(3)
data1
# Out:
# % of restaurant which serve each top cuisines
# Cuisines
# North Indian             9.809264
# North Indian, Chinese    5.355271
# Chinese                  3.709914
# Name: count, dtype: float64

# %%
#pie char for displaying so
plt.title("% of Restaurant that serve each top cusines")
plt.pie(data1.values, labels = data1.index, autopct ="%.3f%%")
plt.legend(loc = 'best', bbox_to_anchor =[0.5,0,0.5,0])
plt.show()

# %% [markdown]
# **TASK 2 (CITY ANALYSIS)**

# %% [markdown]
# **Identify cities with highest no. of restasurant**

# %%
#counting the number of each cities
grp1 = data["City"].value_counts()
grp1
# Out:
# City
# New Delhi    5473
# Gurgaon      1118
# Noida        1080
# Faridabad     251
# Ghaziabad      25
#              ...
# Inverloch       1
# Mohali          1
# Panchkula       1
# Bandung         1
# Randburg        1
# Name: count, Length: 140, dtype: int64

# %%
#finding the city with highest no of restaurant
print("The city with highest no. of restaurant :-", grp1.max())
# Out:
# The city with highest no. of restaurant :- 5473

# %%
#finding top cities with highest no of reaturant 
print("The top cities with highest no of restaurant")
data2 = grp1.head()
print(data2)
# Out:
# The top cities with highest no of restaurant
# City
# New Delhi    5473
# Gurgaon      1118
# Noida        1080
# Faridabad     251
# Ghaziabad      25
# Name: count, dtype: int64

# %%
plt.title("Highest no. of restaurant by cities")
sns.lineplot(data2, marker = "o", ls = ":")
plt.show()

# %% [markdown]
# **Calculate average rating for restaurant in each city**

# %%
#the average rating for rach cities
print("The average rating for restaurant in each cities")
data3 = data.groupby("City")["Aggregate rating"].mean()      
#data3 = data.groupby("City").agg({"Aggregate rating":"mean"})
print(data3)
# Out:
# The average rating for restaurant in each cities
# City
# Abu Dhabi          4.300000
# Agra               3.965000
# Ahmedabad          4.161905
# Albany             3.552941
# Allahabad          3.395000
#                      ...
# Weirton            3.900000
# Wellington City    4.250000
# Winchester Bay     3.200000
# Yorkton            3.300000
# ��stanbul          4.292857
# Name: Aggregate rating, Length: 140, dtype: float64

# %% [markdown]
# **Determine city with highest average rating**

# %%
#city with highest average rating
print("The city with the highest average rating :- ",data3.idxmax())
print("And the average rating of the", data3.idxmax(),"is", (data3.max()) )
# Out:
# The city with the highest average rating :-  Inner City
# And the average rating of the Inner City is 4.9

# %%
#assuming some values and doing slicing 
#and found that the inner city having aggregate rating as 4.9
x = data3.index[54:60]
y = data3.values[54:60]
plt.plot(x,y, marker ="o", ls = "--", color = "black")

# %% [markdown]
# **TASK 3 (PRICE RANGE DISTRIBUTION)**

# %% [markdown]
# **Create a histogram or barchart to visualize the distribution of price ranges among the reaturant**

# %%
#counting all the price range ocuureance
grp3 = data["Price range"].value_counts()
grp3
# Out:
# Price range
# 1    4438
# 2    3113
# 3    1405
# 4     586
# Name: count, dtype: int64

# %%
#ploting the bar graph of no of reaturant vs price range
grp3.plot(xlabel = "Price range", ylabel = "Number of restaurant", kind ="bar", title = "Distribution of price range among the restaurant")
plt.show()

# %% [markdown]
# **Calculate the percentage of restaurant in each price range category**

# %%
#finding the precentage of reataurant in each price range category
print("The percentage of restaurant in each price range category :- ")
g= (grp3/len(data))*100
print(g)
# Out:
# The percentage of restaurant in each price range category :-
# Price range
# 1    46.510166
# 2    32.624188
# 3    14.724376
# 4     6.141270
# Name: count, dtype: float64

# %%
#ploting the pie chart of the above
plt.title("Price range category by percentage of restaurant")
plt.pie(g.values, labels= g.index, autopct = "%.1f%%")
plt.legend(["Price range 1","Price range 2","Price range 3","Price range 4"],ncols = 2, bbox_to_anchor =[1.0,0.7,0.7,0.3], labelspacing =2)
plt.show()

# %% [markdown]
# **TASK 4 (Online delivery)**

# %% [markdown]
# **determine the percentage of restauaramnt that offer online delivery**

# %%
#count the occurance of having online delivery or not
grp4 = data["Has Online delivery"].value_counts()
grp4
# Out:
# Has Online delivery
# No     7091
# Yes    2451
# Name: count, dtype: int64

# %%
#find the percentage of restaurant having the online delivery or not
g = ((grp4/len(data))*100).round(2)
g
# Out:
# Has Online delivery
# No     74.31
# Yes    25.69
# Name: count, dtype: float64

# %%
#pie chart for the above
plt.title("% of Restaurant that offer online delivery")
plt.pie(g.values, labels= g.index, explode = [0,0.2], autopct = "%.1f", shadow = True, startangle = 45, pctdistance=0.7, radius = 1.2)
plt.legend(["Restaurant not offering online delivery","Restaurant offering online delivery"], bbox_to_anchor=[0.5,0.5,1.3,0.5])
plt.show()

# %%
#finding the restaurant count that offer online delivery
grp5 = data["Has Online delivery"].value_counts().get('Yes',0)
print("Number of resaturant that offer online delivery are",grp5)
# Out:
# Number of resaturant that offer online delivery are 2451

# %%
#percentage of restaurant that offer online delivery
g1 =(grp5/len(data))*100
print("% of resaturant that offer the online delivery to customer are", g1)
# Out:
# % of resaturant that offer the online delivery to customer are 25.686438901697755

# %% [markdown]
# **Compare average rating of restaurant with and without online delivery**

# %%
#calculate the mean of the aggregrate rating by the online delivery
grp6 = data.groupby("Has Online delivery").agg({"Aggregate rating":"mean"})
print(grp6)
# Out:
#                      Aggregate rating
# Has Online delivery
# No                           2.463517
# Yes                          3.248837

# %%
x = data[data["Has Online delivery"]=='Yes']["Aggregate rating"].mean()
print('Average rating of restaurant with online delivery are', x)
# Out:
# Average rating of restaurant with online delivery are 3.2488372093023257

# %%
y = data[data["Has Online delivery"]=='No']["Aggregate rating"].mean()
print('Average rating of restaurant without online delivery are', x)
# Out:
# Average rating of restaurant without online delivery are 3.2488372093023257

# %%
#bar plot for the above
grp6.plot(kind ="bar",xlabel= "Online delivery", ylabel ="Average rating", legend =None, title = "Comparision of average rating by online delivery")
plt.show()

# %%
#m = ["With online delivery", "Without online delivery"]
#n = [x,y]
#plt.bar(m,n, color = "yellow")
#plt.show()
